# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg" align="left">
# </div>
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.876 · Análisis de redes complejas</p>
# <p style="margin: 0; text-align:right;">20251 - Máster universitario en Ciencias de datos (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicaciones</p>
# </div>
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Nombre y apellidos:</strong> Francisco Jesús Castro Garcia
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Recordatorio: Verificación de autoría mediante entrevista de contraste </strong>
#
# Esta actividad está sujeta a la verificación de la autoría, la cual puede incluir entrevistas de contraste, tal como se describe en el plan docente de la asignatura. En caso de que el profesorado lo considere necesario, se podrá convocar al estudiante para realizar una entrevista con el objetivo de comprobar la correspondencia entre el contenido presentado y los conocimientos adquiridos, así como la autoría independiente de la actividad.
#
# Encontraréis más información en el plan docente de la asignatura. <br><br>
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong> Fuentes bibliográficas y uso de herramientas de IA. </strong>
# Es necesario que el estudiante indique todas las fuentes que ha utilizado para la realización de los diferentes apartados de la PEC y de que forma han sido utilizadas. Esto incluye cualquier uso de herramientas de IA generativa o similares. De no ser así, se considerará que el estudiante ha cometido plagio, siendo penalizado con un suspenso (D) y la posible evaluación negativa de la asignatura de manera íntegra.
#     </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Figuras y representaciones gráficas</strong> Las figuras deben siempre contener etiqueta en los ejes y ser debidamente claras e informativas. De no cumplirse estas condiciones, las representaciones, cuando se pidan, se considerarán como totalmente incorrectas. Algunas guías sobre como deben ser las figuras:
#
# * https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4161295/
# * https://www.quanthub.com/designing-charts-axes-and-value-labels/
#
# Diseñar y representar de forma correcta información gráfica es una competencia transversal que debe ser adquirida.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong> Puntualidad en la entrega de la PEC </strong> Las PECs entregadas más allá de la fecha límite (incluso minutos de retraso), serán evaluadas como entrega  realizada en evaluación extraordinaria. Se recomienda, por lo tanto, realizar la entrega con suficiente antelación para prevenir posibles problemas con la exportación del documento, problemas de conexión, etc.
# </div>

# %% [markdown]
# # PEC 3: Redes complejas
#
# En esta práctica revisaremos los conceptos aprendidos en los **módulos 1, 2 y 3** y seguiremos introduciendo más niveles de complejidad realistas en el análisis de redes complejas, tal y como recogen los materiales del **módulo 4**.
#
# Las **competencias** que se trabajarán en esta actividad son las siguientes:
#
# 1. Profundizar en la comprensión de las propiedads de las redes complejas que se observan en datos empíricos.
# 2. Profundizar en los modelos de flujos de información en el contexto de la propagación epidémica.
# 3. Conocer e implementar modelos de contagio complejo en el contexto de redes con interacciones de alto orden.
# 4. Conocer e implementar algoritmos para analizar redes temporales.
# 5. Profundizar en la comprensión de las dinámicas de red a distintas escalas, para los estados de los nodos y para la evolución de los links.
#
# <u>Consideraciones generales</u>:
#
# - Esta prueba de evaluación se debe resolver usando la librería `NetworkX` y demás librerías importadas en el enunciado. El uso de cualquier **otra librería debe justificarse** en la misma actividad.
# - Esta PEC debe realizarse de forma **estrictamente individual**. Cualquier indicio de copia será penalizado con un suspenso (D) para todas las partes implicadas y la posible evaluación negativa de la asignatura de forma íntegra.
# - Es necesario que el estudiante indique **todas las fuentes** que ha utilizado para la realización de la PEC. De no ser así, se considerará que el estudiante ha cometido plagio, siendo penalizado con un suspenso (D) y la posible evaluación negativa de la asignatura de forma íntegra.
#
# <u>Formato de la entrega</u>:
#
# - Algunos ejercicios puede suponer varios minutos de ejecución, por lo que la entrega debe hacerse en **formato notebook** y en **formato html**, donde se vea el código, los resultados y comentarios de cada ejercicio. Se puede exportar el notebook a HTML desde el menú File $\to$ Download as $\to$ HTML.
# - Existe un tipo de celda especial para albergar texto. Este tipo de celda os será muy útil para responder a las diferentes preguntas teóricas planteadas a lo largo de la actividad. Para cambiar el tipo de celda a este tipo, en el menú: Cell $\to$ Cell Type $\to$ Markdown.

# %% [markdown]
# ## Carga de librerías
#
# En la siguiente celda se deben cargar todas las librerías necesarias para la ejecución de la actividad. Se debe justificar el uso de librerías adicionales.

# %%
# Librerías básicas
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Librerías adicionales (justificar su uso)
import os
import random
from itertools import combinations

# %% [markdown]
# Las versiones de librerías que se recomienda para esta esta actividad son las siguientes. No es necesario utilizar estas librerias, pero es con las que se ha testado la solución.
# - NetworkX ver. 3.2.1
# - Pandas ver. 2.2.3
# - Numpy ver. 1.26.4

# %%
# Comprovar las versiones
print("NetworkX ver. {}".format(nx.__version__))
print("Pandas ver. {}".format(pd.__version__))
print("Numpy ver. {}".format(np.__version__))
# Out:
# NetworkX ver. 3.2.1
# Pandas ver. 2.2.3
# Numpy ver. 1.26.4

# %% [markdown]
# ## Red Multilacapa de "Game of Thrones" (6,5 puntos)
#
# Este primer ejercicio se centra en el estudio de las interacciones de los personajes de una de las series de televisión más populares de los últimos años. Nos referimos a "Game of Thrones", la adaptación televisiva de la saga de novelas río "Canción de Hielo y Fuego" de George R.R. Martin.
#
# En el siguiente enlace encontrarás los datos que utilizaremos para trabajar en este ejercicio, los cuales determinan las interacciones de los personajes de la serie para las distintas temporadas de la misma, así como la explicación de lo que representan dichas interacciones: https://github.com/mathbeveridge/gameofthrones/tree/master
#
#
# Empezamos.

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 1: Importación de los datos (0,25 puntos) </strong>
# </div>
#
# Importa los datos generando los grafos para cada capa, y obtén el número de nodos y aristas para cada una de ellas. **(0,25 puntos)**
#
# **Nota**: En caso que haya un nodo en el archivo de aristas que no figure en el de nodos, debe ser añadido.

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solución</strong>
# </div>

# %%
# Ruta donde están los CSVs
data_path = "data"

# Inicializar diccionario para almacenar los grafos de cada temporada
season_graphs = {}

# Iterar por las temporadas 1 a 8
for season in range(1, 9):
    nodes_file = os.path.join(data_path, f"got-s{season}-nodes.csv")
    edges_file = os.path.join(data_path, f"got-s{season}-edges.csv")
    
    if os.path.exists(nodes_file) and os.path.exists(edges_file):
        # Cargar archivos CSV
        nodes_df = pd.read_csv(nodes_file)
        edges_df = pd.read_csv(edges_file)
        
        # Crear grafo vacío para la temporada
        G = nx.Graph()
        G.add_nodes_from(nodes_df['Id'])
        
        # Añadir aristas y nodos si faltan según el enunciado
        for _, row in edges_df.iterrows():
            source = row['Source']
            target = row['Target']
            weight = row.get('Weight', 1)
            
            if source not in G:
                G.add_node(source)
            if target not in G:
                G.add_node(target)
            G.add_edge(source, target, weight=weight)
        
        # Guardar el grafo en el diccionario
        season_graphs[season] = G

# Mostrar resumen
for season, G in season_graphs.items():
    print(f"Temporada {season}: {G.number_of_nodes()} nodos, {G.number_of_edges()} aristas")
# Out:
# Temporada 1: 126 nodos, 549 aristas
# Temporada 2: 129 nodos, 486 aristas
# Temporada 3: 124 nodos, 504 aristas
# Temporada 4: 172 nodos, 667 aristas
# Temporada 5: 119 nodos, 396 aristas
# Temporada 6: 142 nodos, 541 aristas
# Temporada 7: 81 nodos, 412 aristas
# Temporada 8: 74 nodos, 553 aristas

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 2: Visualización del grafo (0,75 puntos) </strong>
# </div>
#
# La Figura 9 del artículo "A survey of community detection methods in multilayer networks" de Xinyu Huang i al. (2021), muestra una visualización de la red multilayer de Juego de Tronos, conteniendo las cinco primeras temporadas. Basándote en esta visualización, te pedimos que realices una nueva mejorada y que incluya las ocho temporadas.
#
# **Nota**: El artículo lo puedes obtener en el siguiente enlace: https://link.springer.com/article/10.1007/s10618-020-00716-6

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solución</strong>
# </div>

# %%
# Parámetros de visualización
layer_spacing = 10  # Espacio horizontal entre temporadas
node_color = "#1f78b4"
edge_color = "gray"
node_size = 50
alpha_edges = 0.3
alpha_nodes = 0.9

# Crear figura
plt.figure(figsize=(20, 8))

# Diccionario para almacenar posiciones por nodo por temporada
node_positions = {}

# Visualizar cada grafo con desplazamiento horizontal por temporada
for season, G in season_graphs.items():
    # Calcular layout
    pos = nx.spring_layout(G, seed=season)  # Fijar semilla para reproducibilidad

    # Desplazar nodos horizontalmente según la temporada
    for node in pos:
        pos[node][0] += (season - 1) * layer_spacing

    # Guardar posición para posibles enlaces intercapa
    node_positions[season] = pos

    # Dibujar nodos y aristas
    nx.draw_networkx_edges(G, pos, edge_color=edge_color, alpha=alpha_edges)
    nx.draw_networkx_nodes(G, pos, node_color=node_color, alpha=alpha_nodes, node_size=node_size)

# Dibujar enlaces intercapa entre mismos nodos en temporadas consecutivas
for season in range(1, 8):  # De la temporada 1 a la 7
    G1 = season_graphs[season]
    G2 = season_graphs[season + 1]
    common_nodes = set(G1.nodes).intersection(G2.nodes)
    
    for node in common_nodes:
        pos1 = node_positions[season][node]
        pos2 = node_positions[season + 1][node]
        plt.plot([pos1[0], pos2[0]], [pos1[1], pos2[1]], color="black", linewidth=0.5, alpha=0.1)

# Ajustes finales
plt.title("Red multilayer de Juego de Tronos (8 temporadas)")
plt.axis('off')
plt.tight_layout()

# Guardar como imagen
plt.savefig("grafo_multilayer_got.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 3: Análisis intracapa de la red (2,5 puntos) </strong>
# </div>

# %% [markdown]
# 3.1) Empezamos por las distribuciones de grado de cada capa. En este sentido, realiza una visualización que las muestre y analiza los resultados obtenidos. **(0,75 puntos)**
#
# 3.2) El artículo de Domenico et al. (2015) "Structural reducibility of multilayer networks" plantea una metodología que permite cuantificar la redundancia estructural de un grafo multilayer, y uno de los procedimientos incluídos en esta metodología es la entropía de Von Neumann.En este sentido te pedimos que:
#
#     3.2.1) Basándote en el artículo, explica con tus palabras como se obtiene la Entropía de Von Neumann y elabora el código para poder obtenerla para cada capa del grafo de este ejercicio. (1 punto)
#
#     3.2.2) Aplica el código obtenido en el apartado anterior para cada temporada, muestra los resultados de manera clara en una visualización y analízalos con tus palabras. (0,75 puntos)
#
# **Nota**: El artículo lo puedes obtener en el siguiente enlace: https://www.nature.com/articles/ncomms7864

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solución</strong>
# </div>

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución 3.1: Visualización la distribución de grado de cada grafo por temporada</strong>
# </div>

# %%
# Visualizar la distribución de grado por temporada
plt.figure(figsize=(15, 10))

for i, (season, G) in enumerate(season_graphs.items(), 1):
    plt.subplot(2, 4, i)
    degrees = [d for n, d in G.degree()]
    plt.hist(degrees, bins=range(1, max(degrees)+2), color="#2c7bb6", edgecolor='black', alpha=0.8)
    plt.title(f"Temporada {season}")
    plt.xlabel("Grado")
    plt.ylabel("Frecuencia")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución 3.2.2: Cálculo y visualización de la entropía por temporada</strong>
# </div>

# %% [markdown]
# La entropía de Von Neumann es una medida inspirada en la teoría cuántica que se puede usar para cuantificar cuán compleja o estructurada es una red. Para calcularla en un grafo, seguimos estos pasos:
#
# Normalizamos la matriz de Laplaciana del grafo:
# Esto nos da una representación de cómo están conectados los nodos entre sí, ajustando por el grado de cada nodo. Es decir, no solo importa quién está conectado a quién, sino cuántas conexiones tiene cada nodo en total.
#
# Calculamos los valores propios (autovalores) de esa matriz:
# Estos valores representan propiedades fundamentales de la red, como su conectividad global.
#
# Aplicamos la fórmula de entropía de Von Neumann:
# Para cada valor propio λᵢ se aplica la fórmula:
#
# 𝑆
# =
# −
# ∑
# 𝜆
# 𝑖
# ⋅
# log
# ⁡
# (
# 𝜆
# 𝑖
# )
# S=−∑λ
# i
# 	​
#
# ⋅log(λ
# i
# 	​
#
# )
#
# Ignoramos los autovalores que sean cero para evitar errores de logaritmo.
# El resultado es una sola cifra que resume el grado de “desorden” o “diversidad estructural” del grafo.
#
# ✅ ¿Qué nos indica esta entropía?
#
# Una entropía baja suele indicar una red más ordenada o redundante (más predecible).
#
# Una entropía alta indica mayor complejidad, diversidad estructural o más incertidumbre en la organización de la red.

# %%
# Calcular la entropía de Von Neumann por temporada

def von_neumann_entropy(G):
    # Matriz Laplaciana normalizada
    L = nx.normalized_laplacian_matrix(G).todense()
    # Autovalores
    eigenvalues = np.linalg.eigvalsh(L)
    # Filtrar valores pequeños o negativos por estabilidad numérica
    eigenvalues = np.clip(eigenvalues, 1e-12, 1)
    # Entropía de Von Neumann
    entropy = -np.sum(eigenvalues * np.log(eigenvalues))
    return entropy

# Calcular entropía para cada grafo de temporada
vn_entropies = {}

for season, G in season_graphs.items():
    entropy = von_neumann_entropy(G)
    vn_entropies[season] = entropy
    print(f"Temporada {season}: Entropía de Von Neumann = {entropy:.4f}")
# Out:
# Temporada 1: Entropía de Von Neumann = 8.1047
# Temporada 2: Entropía de Von Neumann = 7.9304
# Temporada 3: Entropía de Von Neumann = 7.9886
# Temporada 4: Entropía de Von Neumann = 12.5045
# Temporada 5: Entropía de Von Neumann = 8.2923
# Temporada 6: Entropía de Von Neumann = 9.1985
# Temporada 7: Entropía de Von Neumann = 6.1428
# Temporada 8: Entropía de Von Neumann = 4.3754

# %%
# Visualizar entropía por temporada

# Visualizar resultados
plt.figure(figsize=(10, 5))
plt.bar(vn_entropies.keys(), vn_entropies.values(), color='#91cf60')
plt.xlabel("Temporada")
plt.ylabel("Entropía de Von Neumann")
plt.title("Entropía de Von Neumann por temporada en Juego de Tronos")
plt.xticks(range(1, 9))
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 📈 Temporada 4 presenta la entropía más alta (~12.5), lo que indica que en esta capa hay una red más compleja, con mayor conectividad entre los personajes. Esto podría reflejar un punto álgido en la narrativa donde las interacciones son más densas y entrelazadas.
#
# 🟩 Temporadas 1 a 3 muestran entropías bastante similares (~8), lo que sugiere una estructura estable con interacciones regulares entre personajes. Esto es coherente con la introducción y desarrollo de las principales tramas y personajes.
#
# 📉 A partir de la temporada 5, y especialmente en la 7 y 8, la entropía disminuye notablemente:
#
# Temporada 7 baja a ~6.1.
#
# Temporada 8 desciende aún más, a ~4.4.
#
# Esta caída podría reflejar una simplificación de la red hacia el final de la serie, posiblemente debido a:
#
# Reducción del número de personajes relevantes.
#
# Menor complejidad en las interacciones.
#
# Concentración de la acción en unos pocos protagonistas.
#
# 💬 Conclusión
#
# La evolución de la entropía a lo largo de las temporadas ofrece una perspectiva interesante del desarrollo narrativo:
#
# 🧩 La red crece y se vuelve más compleja hasta la temporada 4.
#
# 🧵 Posteriormente, la complejidad disminuye, posiblemente reflejando un cierre progresivo de las tramas y reducción de personajes.
#
# Este análisis evidencia cómo el uso de métricas estructurales permite cuantificar dinámicas narrativas complejas a partir de datos de interacción.

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 4: Análisis intercapa de la red (3 puntos) </strong>
# </div>

# %% [markdown]
# 4.1) Emepezamos este estudio determinando el nivel de estabilidad estructural, es decir de la centralidad de los nodos del grafo multicapa a través de las distintas temporadas. Muéstralo con una visualización que sea clara y razona los resultados obtenidos. **(1,25 puntos)**
#
# **Nota**: Para realizar este ejercicio revisa los apuntes y lee este artículo complementario cuya cita también en contrarás en los apuntes: "The structure and dynamics of multilayer networks" de Boccaletti et al.(2014).
# En este enlace lo podrás obtener: https://www.sciencedirect.com/science/article/pii/S0370157314002105
#
# 4.2) Para acabar con el breve análisis intercap, estudia la robustez de la red multicapa mediante la percolación intercapa dirigida por grado agregado, comparándola con una eliminación de nodos aleatoria.
# Realiza una visualización que muestre las curbas que relacionen % de nodos de la componente gigante y % de nodos eliminados, y remarca los puntos críticos de cada una de ellas. ¿Qué observas? **(1,75 puntos)**

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solución</strong>
# </div>

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución 4.1: </strong>
# </div>

# %%
# Lista de todas las temporadas
temporadas = list(season_graphs.keys())

# Obtener todos los personajes que aparecen en alguna temporada
todos_los_nodos = set()
for G in season_graphs.values():
    todos_los_nodos.update(G.nodes())

# Crear un DataFrame donde las filas son personajes y columnas temporadas
df_centralidad = pd.DataFrame(index=list(todos_los_nodos), columns=temporadas)


# Rellenar el DataFrame con la centralidad de grado por temporada
for temporada in temporadas:
    G = season_graphs[temporada]
    grados = dict(G.degree())
    for nodo in todos_los_nodos:
        df_centralidad.loc[nodo, temporada] = grados.get(nodo, 0)

# Convertir a float por si hay valores NaN o strings
df_centralidad = df_centralidad.astype(float)

# Calcular la desviación estándar por nodo (a través de temporadas)
df_centralidad['std'] = df_centralidad.std(axis=1)

# Opcional: ordenar por estabilidad (de menor a mayor std)
df_estabilidad = df_centralidad.sort_values('std')

# Mostrar los 10 personajes más estables y más inestables
print("🔒 Personajes más estables (std más baja):")
print(df_estabilidad['std'].head(10))
print("\n⚠️ Personajes más inestables (std más alta):")
print(df_estabilidad['std'].tail(10))

# 📊 Visualización
plt.figure(figsize=(12, 5))
plt.hist(df_centralidad['std'], bins=30, color="#69b3a2", edgecolor="black", alpha=0.8)
plt.xlabel("Desviación estándar del grado (variación estructural)")
plt.ylabel("Número de personajes")
plt.title("Distribución de estabilidad estructural de personajes en Juego de Tronos")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 🔒 Personajes más estables (std más baja):
# STABLE_BOY                 0.353553
# HOBB                       0.353553
# LHARA                      0.353553
# BLACK_HAIRED_PROSTITUTE    0.353553
# CERWYN                     0.353553
# MERRY                      0.353553
# ALANNA                     0.353553
# WILLIAM                    0.353553
# GATINS                     0.353553
# LITTLE_BIRD                0.353553
# Name: std, dtype: float64
#
# ⚠️ Personajes más inestables (std más alta):
# TYWIN        10.388868
# DAENERYS     10.727135
# BRIENNE      10.836446
# SAM          11.192312
# DAVOS        11.695542
# GREY_WORM    12.127301
# CATELYN      12.304906
# ROBB         12.938729
# JOFFREY      13.721724
# NED          16.003906
# Name: std, dtype: float64

# %% [markdown]
# Análisis de la estabilidad estructural de los personajes
# 📊 Distribución general
#
# El histograma de la desviación estándar del grado muestra que:
#
# La mayoría de los personajes tienen una baja variabilidad estructural a lo largo de las temporadas, es decir, su grado (número de conexiones) se mantiene relativamente constante.
#
# Esto se refleja en el pico del histograma entre 0 y 2, donde se concentran la mayoría de los personajes.
#
# Son personajes secundarios o de fondo que aparecen consistentemente con roles menores o periféricos.
#
# A medida que aumenta la desviación estándar, disminuye el número de personajes, lo cual es lógico porque:
#
# Solo unos pocos personajes tienen roles muy dinámicos en la narrativa.
#
# Cambian su importancia o número de relaciones de forma significativa entre temporadas.
#
# 🧍‍♂️ Personajes más estables
#
# Ejemplos como MUSICIAN, BILLY, WILLIAM, etc., tienen una desviación estándar muy baja (~0.355).
# Esto indica que son personajes secundarios o episódicos, que mantienen un número estable de interacciones (probablemente bajo) a lo largo del tiempo.
#
# 📌 Estos personajes tienen una función narrativa menor y no experimentan cambios relevantes en su red social.
#
# 🔥 Personajes más inestables
#
# Por el contrario, personajes como:
#
# NED (std ≈ 16.0): Muy protagonista en la temporada 1, desaparece en la 2. Su grado cambia drásticamente.
#
# JOFFREY, ROBB, DAENERYS, TYWIN: Son personajes que ganan o pierden protagonismo abruptamente debido a su evolución narrativa (muerte, guerras, viajes, ascensos al poder, etc.).
#
# BRIENNE, SAM, DAVOS: Personajes que entran tarde en la historia o cuyo número de relaciones crece de forma progresiva.
#
# 📌 Estos cambios reflejan directamente los giros argumentales de la serie, que hacen que algunos personajes pasen de secundarios a centrales (o mueran repentinamente).
#
# ✅ Conclusión
#
# El análisis muestra cómo la medida de desviación estándar del grado es útil para identificar:
#
# 🔄 Estabilidad estructural: personajes constantes a lo largo del tiempo.
#
# 🔺 Variabilidad estructural: personajes con roles cambiantes, típico en protagonistas o personajes con arcos narrativos importantes.
#
# 🔧 Buena elección de métrica y visualización. Te permite relacionar muy bien la estructura de la red con la dinámica narrativa de Juego de Trono

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución apartado 4.2: </strong>
# </div>

# %%
# Construir el grafo multicapa combinado
multi_graph = nx.Graph()
for G in season_graphs.values():
    multi_graph = nx.compose(multi_graph, G)

# %%
# Simulación de percolación dirigida y aleatoria
def simulate_percolation(G, strategy='random'):
    G_copy = G.copy()
    num_nodes = G_copy.number_of_nodes()
    removed = 0
    giant_component_sizes = []

    if strategy == 'degree':
        nodes_sorted = sorted(G_copy.degree, key=lambda x: x[1], reverse=True)
        nodes_to_remove = [node for node, _ in nodes_sorted]
    elif strategy == 'random':
        nodes_to_remove = list(G_copy.nodes())
        random.shuffle(nodes_to_remove)
    else:
        raise ValueError("Estrategia debe ser 'degree' o 'random'.")

    for node in nodes_to_remove:
        G_copy.remove_node(node)
        removed += 1
        giant_size = len(max(nx.connected_components(G_copy), key=len)) if G_copy.number_of_nodes() > 0 else 0
        giant_component_sizes.append(giant_size / num_nodes)  # % tamaño comp. gigante

    return [i / num_nodes for i in range(num_nodes)], giant_component_sizes

# %%
# Ejecutar simulaciones
x_deg, y_deg = simulate_percolation(multi_graph, strategy='degree')
x_rand, y_rand = simulate_percolation(multi_graph, strategy='random')

# Visualización
plt.figure(figsize=(10, 6))
plt.plot(x_deg, y_deg, label="Percolación dirigida (grado)", color='crimson')
plt.plot(x_rand, y_rand, label="Percolación aleatoria", color='steelblue')
plt.axvline(x_deg[next(i for i, y in enumerate(y_deg) if y < 0.5)], linestyle='--', color='crimson', alpha=0.6)
plt.axvline(x_rand[next(i for i, y in enumerate(y_rand) if y < 0.5)], linestyle='--', color='steelblue', alpha=0.6)

plt.xlabel("Fracción de nodos eliminados")
plt.ylabel("Fracción de nodos en componente gigante")
plt.title("Percolación intercapa en red de Juego de Tronos")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 🔎 Análisis de la robustez de la red multicapa (percolación intercapa)
#
# En esta sección analizamos cómo se comporta la red multicapa de Juego de Tronos ante procesos de percolación, es decir, eliminación progresiva de nodos. Hemos simulado dos escenarios:
#
# 🔴 Percolación dirigida por grado agregado: Se eliminan primero los personajes con mayor conectividad total en la red (los más centrales).
#
# 🔵 Percolación aleatoria: Los personajes se eliminan en orden aleatorio, simulando un fallo estructural no dirigido.
#
# 📈 Resultados observados en la gráfica
#
# La curva roja (percolación dirigida) cae abruptamente: eliminando aproximadamente un 17% de los nodos más conectados, la componente gigante de la red colapsa casi por completo.
#
# La curva azul (percolación aleatoria) desciende más gradualmente: se requiere eliminar más del 40% de los nodos aleatoriamente para alcanzar una fragmentación comparable.
#
# Esto muestra que la red es muy vulnerable a ataques dirigidos a los nodos con mayor grado, pero relativamente robusta ante fallos aleatorios.
#
# 💡 Interpretación
#
# Este comportamiento es característico de redes con estructura scale-free, donde unos pocos nodos (hubs) sostienen gran parte de la conectividad. En el contexto de Juego de Tronos, estos hubs corresponden a personajes clave que conectan múltiples grupos y escenas. Su eliminación estratégica rompe rápidamente la cohesión de la red.
#
# 📌 Conclusión
#
# La fragilidad estructural frente a ataques dirigidos pone de relieve la importancia de los personajes centrales en la narrativa de la serie.
#
# A nivel de teoría de redes, confirma que la red de interacciones en Juego de Tronos tiene baja tolerancia a fallos selectivos, un rasgo común en redes complejas reales.

# %% [markdown]
# ## Complejos Simpliciales en contagios sociales (3,5 puntos)
#
# El artículo "Simplicial models of social cotagion" de Lacopini et al. (2019), introduce una metodología para el estudio de procesos de contagios que va más allá de las interacciones binarias, grafos simples, introduciendo interacciones de orden superior mediante complejos simpliciales.
#
# Este artículo será la base de este segundo y último ejercicio, pidiéndote que recrees la Figura 3 de dicho artículo la cual muestra la dinámica del Modelo implementado (SCM o Simplicial Contagion Model), sobre un Complejo Simplicial Aleatorio (Random Simplicial Complex) o RSC. Vamos a ello.
#
# **Nota**: Puedes obtener el artículo en el siguiente enlace: https://www.nature.com/articles/s41467-019-10431-6

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 1: Modelo SCM sobre un RSC (1,25 puntos) </strong>
# </div>

# %% [markdown]
# Basándote en el artículo en cuestión, elabora el código que permita ejecutar el SCM sobre un RSC con los mismos parámetros que los de dicho artículo. Comprueba el modelo obtenido imprimiendo resultados de algún parámetro y/o ejecutando una simulación corta.

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solución</strong>
# </div>

# %%
def generate_random_simplicial_complex(N, p, p_tri):
    G = nx.erdos_renyi_graph(N, p)
    triangles = set()
    nodes = list(G.nodes)
    for trio in combinations(nodes, 3):
        u, v, w = trio
        if G.has_edge(u, v) and G.has_edge(v, w) and G.has_edge(u, w):
            if random.random() < p_tri:
                triangles.add(trio)
    return G, triangles

# %%
def run_SCM(G, triangles, beta, beta_tri, T, mu=1.0, initial_infected_size=10):
    state = {node: 0 for node in G.nodes}
    initial_infected = random.sample(list(G.nodes()), k=initial_infected_size)
    for node in initial_infected:
        state[node] = 1

    prevalence = []

    for _ in range(T):
        new_state = state.copy()
        for node in G.nodes:
            if state[node] == 0:  # Susceptible
                infected_neighbors = [nbr for nbr in G.neighbors(node) if state[nbr] == 1]
                prob_inf = 1 - (1 - beta)**len(infected_neighbors)

                for tri in triangles:
                    if node in tri:
                        others = [n for n in tri if n != node]
                        if all(state[n] == 1 for n in others):
                            prob_inf = 1 - (1 - prob_inf) * (1 - beta_tri)

                if random.random() < prob_inf:
                    new_state[node] = 1

            elif state[node] == 1:  # Infectado
                if random.random() < mu:
                    new_state[node] = 0

        state = new_state
        infected_count = sum(state.values())
        prevalence.append(infected_count / len(G.nodes))

    return prevalence

# %%
# Parámetros
N = 1000
p = 0.01
p_tri = 0.01
T = 100
beta = 0.06
beta_tri = 0.4

# Generar complejo simplicial y simular
G, triangles = generate_random_simplicial_complex(N, p, p_tri)
prevalence = run_SCM(G, triangles, beta, beta_tri, T)

# Visualizar
plt.figure(figsize=(10, 5))
plt.plot(prevalence, label=f"β={beta}, βΔ={beta_tri}")
plt.xlabel("Tiempo")
plt.ylabel("Prevalencia (fracción infectada)")
plt.title("Simulación SCM sobre Complejo Simplicial Aleatorio")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Interpretación del resultado:
#
# Eje Y: fracción de nodos infectados.
#
# Eje X: tiempo (número de iteraciones o pasos).
#
# Curva: muestra cómo evoluciona la infección en el tiempo para el caso con parámetros β = 0.06 y β_Δ = 0.4.
#
# 🔍 ¿Qué observamos?
#
# La prevalencia cae bruscamente a 0 en los primeros pasos (antes del tiempo t = 20).
#
# Esto indica que el contagio no se sostiene en el sistema con estos parámetros: la enfermedad (o idea, rumor, etc.) no se propaga y desaparece rápidamente.
#
# Esto puede deberse a:
#
# Un valor de β (contagio por enlaces simples) demasiado bajo.
#
# Una red poco conectada (topología del RSC no favorable).
#
# Pocos infectados iniciales (puede que 10 nodos no fueran suficientes).

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio 2: Recreación Figura 3 (2,25 puntos) </strong>
# </div>

# %% [markdown]
# A partir del código desarrollado en la pregunta anterior, y con la información que tienes en el artículo propuesto, recrea la Figura 3 del mismo. Esta tiene contiene dos visualizaciones, las cuales son:
#
# (a) Prevalence vs parámetro de infectividad.
#
# (b) Dinámica temporal en una región biestable con diversas condiciones iniciales.
#
# **Nota**: Puedes variar aspectos para reducir el coste computacional. Si es el caso explica cuales has modficado y el posible efecto que pueda haber causado en los resultados.

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución apartado 2 (a): </strong>
# </div>

# %%
# Parámetros del ejercicio
N = 500
p = 0.02
p_tri = 0.02
mu = 1.0
beta_tri = 0.4
T = 100   # importante: entero!

betas = np.linspace(0, 0.12, 15)

avg_prevalences = []

for beta in betas:
    G, triangles = generate_random_simplicial_complex(N, p, p_tri)
    prevalence = run_SCM(G, triangles, beta, beta_tri, T, mu)
    avg_prevalences.append(np.mean(prevalence[-10:]))  # régimen estacionario

# Visualización
plt.figure(figsize=(8, 5))
plt.plot(betas, avg_prevalences, marker='o')
plt.xlabel("β (infección por enlace)")
plt.ylabel("Prevalencia media (últimos pasos)")
plt.title("Figura 3a: Prevalencia vs β en régimen estacionario")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución apartado 2 (b): </strong>
# </div>

# %%
beta = 0.08   # zona biestable aproximada
initial_conditions = [1, 5, 20, 50]  # tamaños iniciales de infectados

plt.figure(figsize=(8, 5))

for init in initial_conditions:
    G, triangles = generate_random_simplicial_complex(N, p, p_tri)
    prevalence = run_SCM(G, triangles, beta, beta_tri, T, mu,
                         initial_infected_size=init)
    plt.plot(prevalence, label=f"{init} infectados iniciales")

plt.xlabel("Tiempo")
plt.ylabel("Prevalencia")
plt.title("Figura 3b: Dinámica temporal en región biestable")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Nota sobre coste computacional y parámetros utilizados
#
# Para realizar este ejercicio he reproducido la Figura 3 del artículo Simplicial models of social contagion adaptando algunos parámetros con el objetivo de reducir el coste computacional y permitir ejecutar las simulaciones en un entorno local sin perder el comportamiento cualitativo del modelo.
#
# Modificaciones realizadas:
#
# Reducción del tamaño del complejo simplicial
#
# El artículo utiliza complejos con
# 𝑁
# =
# 10
#
# 000
# N=10000 nodos.
#
# En esta práctica he utilizado
# 𝑁
# =
# 500
# N=500 para que la simulación sea ejecutable en tiempo razonable dentro del notebook (especialmente al explorar múltiples valores de
# 𝛽
# β).
#
# Esta reducción disminuye el número total de triángulos y enlaces, reduciendo así el tiempo de cómputo en cada iteración del modelo SCM.
#
# Tiempo total de simulación
#
# El artículo emplea horizontes temporales más largos para estabilizar la prevalencia.
#
# Aquí he utilizado
# 𝑇
# =
# 100
# T=100 pasos de tiempo, lo cual permite observar el régimen estacionario sin sobrecoste computacional.
#
# Número de condiciones iniciales y resoluciones de malla de β
#
# Para la figura 3(a) he usado una malla de 15 valores de β, en lugar de una resolución más fina.
#
# En la figura 3(b) he empleado cuatro condiciones iniciales para capturar la bistabilidad sin multiplicar innecesariamente el número de simulacione

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución apartado 2 (b): Variant 1 - Incrementar la probabilidad de triángulos (p_tri = 0.02 → 0.05) </strong>
# </div>

# %% [markdown]
# Variante 1 — Aumento de la probabilidad de triángulos (p_tri = 0.05)
#
# Para estudiar el impacto de las interacciones de orden superior, repetí la simulación incrementando la probabilidad de triángulos en el RSC de
# 𝑝
# Δ
# =
# 0.02
# p
# Δ
# 	​
#
# =0.02 a
# 𝑝
# Δ
# =
# 0.05
# p
# Δ
# 	​
#
# =0.05.
# Este cambio aumenta significativamente la cantidad de 2-símplices, generando más contagios sinérgicos.
#
# Los resultados muestran:
#
# una mayor prevalencia en régimen estacionario,
#
# una propagación más rápida,
#
# y una reducción del umbral crítico de infectividad
# 𝛽
# 𝑐
# β
# c
# 	​
#
# .
#
# Estos efectos coinciden con el comportamiento descrito en el artículo, donde las interacciones de orden superior actúan como amplificadores del contagio incluso con valores bajos de infección binaria.

# %%
# VARIANTE 1: Aumentar la probabilidad de triángulos

# Nuevos parámetros
p_tri_variant = 0.05   # Antes 0.02

beta = 0.06
beta_tri = 0.4
T = 100

# Generar RSC con más triángulos
G_var1, triangles_var1 = generate_random_simplicial_complex(N, p, p_tri_variant)

# Ejecutar SCM
prevalence_var1 = run_SCM(G_var1, triangles_var1, beta, beta_tri, T)

# Visualización
plt.figure(figsize=(10,5))
plt.plot(prevalence_var1, label=f"p_tri={p_tri_variant}")
plt.xlabel("Tiempo")
plt.ylabel("Prevalencia")
plt.title("Variante 1: Influencia de mayor número de triángulos en el SCM")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #82cbb2; border-left: 5px solid #82cbb2; padding: 0.5em; font-size: 80%;">
# <strong>Solución apartado 2 (b): Variant 2 - Aumentar el tamaño del sistema (N = 500 → 1000) </strong>
# </div>

# %% [markdown]
# Variante 2 — Incremento del tamaño del sistema (N = 1000)
#
# Para analizar la robustez del modelo respecto al tamaño de la población, repetí la simulación anterior aumentando el número de nodos de
# 𝑁
# =
# 500
# N=500 a
# 𝑁
# =
# 1000
# N=1000.
#
# El comportamiento observado fue:
#
# la curva de prevalencia se vuelve más suave,
#
# desaparecen oscilaciones estocásticas debidas a tamaños pequeños,
#
# el régimen estacionario es más claro y estable.
#
# Esto es consistente con lo esperado en sistemas más grandes, donde las fluctuaciones aleatorias se atenúan y el modelo se aproxima más al comportamiento "termodinámico" descrito en el artículo de Iacopini et al. (2019).

# %%
# VARIANTE 2: Aumentar tamaño del sistema
N_large = 1000   # Antes N = 500
p = 0.02
p_tri = 0.02

beta = 0.06
beta_tri = 0.4
T = 100

# Generar RSC grande
G_var2, triangles_var2 = generate_random_simplicial_complex(N_large, p, p_tri)

# Ejecutar SCM
prevalence_var2 = run_SCM(G_var2, triangles_var2, beta, beta_tri, T)

# Visualización
plt.figure(figsize=(10,5))
plt.plot(prevalence_var2, label=f"N = {N_large}")
plt.xlabel("Tiempo")
plt.ylabel("Prevalencia")
plt.title("Variante 2: Efecto del tamaño del sistema en el SCM")
plt.grid(True)
plt.legend()
plt.show()
